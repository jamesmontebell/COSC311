# %%
import pandas as pd
import numpy as np

# %%
df_b = pd.read_csv("Bejaia_Region.csv")
df_s = pd.read_csv("Sidi-Bel_Abbes_Region.csv")

df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    float64
#  13  Classes      122 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB

# %%
df_b[' Ws'].unique()
# Out:
# array([18, 13, 22, 16, 14, 15, 12, 19, 21, 20, 17, 26, 11])

# %%
df_s[' Ws'].unique()
# Out:
# array([12, 13, 14, 11, 17, 18, 15, 21, 16, 10,  9, 19,  8,  6, 29])

# %%
len(df_b)
# Out:
# 122

# %%
len(df_s)
# Out:
# 122

# %%
from matplotlib import pyplot as plt

# %%
temp = plt.plot(range(len(df_b['day'])), df_b['Temperature'])
plt.title('Change in temperature with time.')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.show()

# %%
temp = plt.plot(range(len(df_s['day'])), df_s['Temperature'])
plt.title('Change in temperature with time.')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.show()

# %%
plt.scatter(df_s['Temperature'], df_s['FWI'])
plt.title("Temperature & FWI")
plt.xlabel('Temperature')
plt.ylabel('FWI')
plt.yticks(np.arange(df_s['FWI'].min(), df_s['FWI'].max(), 2))

plt.show()

# %%
# june = df_b[' RH'][df_b['month'] == 6]
# july = df_b[' RH'][df_b['month'] == 7]
# august = df_b[' RH'][df_b['month'] == 8]
# september = df_b[' RH'][df_b['month'] == 9]
import numpy as np

y = 0
avgs = [sum([y + x for x in df_b[' RH'][df_b['month'] == month]])/len(df_b[' RH'][df_b['month'] == month]) for month in df_b['month'].unique()]

plt.bar(range(len(avgs)), avgs)
plt.xlabel("Month")
plt.ylabel('Average')
plt.title("Average RH Per Month")
plt.xticks(np.arange(0, 3.5, 1), [6, 7, 8, 9])
plt.yticks(np.arange(60, 75, 1))
plt.axis([-.5, 3.5, 60, 75])
plt.show()

# I'm not quite sure which way you wanted it

plt.hist(avgs)
plt.xlabel("Averages")
plt.ylabel('Occurance of Averages')
plt.title("Average RH Per Month")
# Out:
# Text(0.5, 1.0, 'Average RH Per Month')

# %%
rain = [max([rain for rain in df_b['Rain '][df_b['month'] == month]]) for month in df_b['month'].unique()]

plt.bar(range(len(rain)), rain)
plt.xlabel("Month")
plt.ylabel('Rain')
plt.title("Most Rain in a Day Per Month")
plt.xticks(np.arange(0, 3.5, 1), [6, 7, 8, 9])
plt.show()

# %%
wind = df_s[' Ws']

plt.hist(wind, bins=5)
plt.xlabel('Wind Speed Value')
plt.ylabel('Occurance of Wind Speed Value')
plt.title('Wind Speed Distribution')
plt.show()

# %%
plt.plot(range(len(df_s[' RH'])), df_s['Temperature'] )
plt.xlabel("Relative Humidity")
plt.ylabel('Temperature')
plt.title('Correlation between Relative Humidity and Temperature')
plt.show()

# %%
rh = df_b[' RH']
plt.bar(rh, df_b['day'])
plt.xticks(range(40, 100, 10))
plt.xlabel("Relative Humidity")
plt.ylabel("Days")
plt.title("Distribution of Relative Humidity")
plt.show()

# %%
# avgs = [sum([y + x for x in df_b['Temperature'][df_b['month'] == month]])/len(df_b[' RH'][df_b['month'] == month]) for month in df_b['month'].unique()]
# print(avgs)

# avg = df_b['Temperature'][(df_b['month'] == 6) & df_b['Classes  '] == 'not fire'] 
# print(avg)

noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]

# plt.bar(6, noFire[0][0])
# plt.bar(7, noFire[1][0])
# plt.bar(8, noFire[2][0])
# plt.bar(9, noFire[3][0])

noFireList = []
noFireList.append(noFire[0][0])
noFireList.append(noFire[1][0])
noFireList.append(noFire[2][0])
noFireList.append(noFire[3][0])

withFireList = []
withFireList.append(withFire[0][0])
withFireList.append(withFire[1][0])
withFireList.append(withFire[2][0])
withFireList.append(withFire[3][0])

plt.subplot(1, 2, 1)
plt.plot(range(6, 10), noFireList, label='No Fire', color='g')
plt.xticks(range(6, 10))
plt.legend(loc='lower center')
plt.xlabel('Months')
plt.ylabel('Average Temperature')
plt.title('Average Temperature Each Month no fire')

plt.subplot(1, 2, 2)
plt.plot(range(6, 10), withFireList, label='Fire')
plt.xticks(range(6, 10))
plt.legend(loc='lower center')

plt.xlabel('Months')
plt.ylabel('Average Temperature')
plt.title('Average Temperature Each Month fire')
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=1,
                    wspace=1.5)
plt.show()
# Out:
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/2785956778.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]

# %%
# %%
import pandas as pd
import numpy as np

# %%
df_b = pd.read_csv("/Users/jamesmontebell/Github/cosc311/lab2/Bejaia_Region.csv")
df_s = pd.read_csv("/Users/jamesmontebell/Github/cosc311/lab2/Sidi-Bel_Abbes_Region.csv")

df_b.info()


# %%
df_b[' Ws'].unique()

# %%
df_s[' Ws'].unique()

# %%
len(df_b)

# %%
len(df_s)

# %%
from matplotlib import pyplot as plt

# %%
temp = plt.plot(range(len(df_b['day'])), df_b['Temperature'])
plt.title('Change in temperature with time.')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.show()

# %%
temp = plt.plot(range(len(df_s['day'])), df_s['Temperature'])
plt.title('Change in temperature with time.')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.show()

# %%
plt.scatter(df_s['Temperature'], df_s['FWI'])
plt.title("Temperature & FWI")
plt.xlabel('Temperature')
plt.ylabel('FWI')
plt.yticks(np.arange(df_s['FWI'].min(), df_s['FWI'].max(), 2))

plt.show()



# %%
# june = df_b[' RH'][df_b['month'] == 6]
# july = df_b[' RH'][df_b['month'] == 7]
# august = df_b[' RH'][df_b['month'] == 8]
# september = df_b[' RH'][df_b['month'] == 9]
import numpy as np

y = 0
avgs = [sum([y + x for x in df_b[' RH'][df_b['month'] == month]])/len(df_b[' RH'][df_b['month'] == month]) for month in df_b['month'].unique()]

plt.bar(range(len(avgs)), avgs)
plt.xlabel("Month")
plt.ylabel('Average')
plt.title("Average RH Per Month")
plt.xticks(np.arange(0, 3.5, 1), [6, 7, 8, 9])
plt.yticks(np.arange(60, 75, 1))
plt.axis([-.5, 3.5, 60, 75])
plt.show()

# I'm not quite sure which way you wanted it

plt.hist(avgs)
plt.xlabel("Averages")
plt.ylabel('Occurance of Averages')
plt.title("Average RH Per Month")




# %%
rain = [max([rain for rain in df_b['Rain '][df_b['month'] == month]]) for month in df_b['month'].unique()]

plt.bar(range(len(rain)), rain)
plt.xlabel("Month")
plt.ylabel('Rain')
plt.title("Most Rain in a Day Per Month")
plt.xticks(np.arange(0, 3.5, 1), [6, 7, 8, 9])
plt.show()


# %%
wind = df_s[' Ws']

plt.hist(wind, bins=5)
plt.xlabel('Wind Speed Value')
plt.ylabel('Occurance of Wind Speed Value')
plt.title('Wind Speed Distribution')
plt.show()



# %%
plt.plot(range(len(df_s[' RH'])), df_s['Temperature'] )
plt.xlabel("Relative Humidity")
plt.ylabel('Temperature')
plt.title('Correlation between Relative Humidity and Temperature')
plt.show()

# %%
rh = df_b[' RH']
plt.bar(rh, df_b['day'])
plt.xticks(range(40, 100, 10))
plt.xlabel("Relative Humidity")
plt.ylabel("Days")
plt.title("Distribution of Relative Humidity")
plt.show()

# %% [markdown]
# 

# %%
# avgs = [sum([y + x for x in df_b['Temperature'][df_b['month'] == month]])/len(df_b[' RH'][df_b['month'] == month]) for month in df_b['month'].unique()]
# print(avgs)

# avg = df_b['Temperature'][(df_b['month'] == 6) & df_b['Classes  '] == 'not fire'] 
# print(avg)

noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]

# plt.bar(6, noFire[0][0])
# plt.bar(7, noFire[1][0])
# plt.bar(8, noFire[2][0])
# plt.bar(9, noFire[3][0])

noFireList = []
noFireList.append(noFire[0][0])
noFireList.append(noFire[1][0])
noFireList.append(noFire[2][0])
noFireList.append(noFire[3][0])

withFireList = []
withFireList.append(withFire[0][0])
withFireList.append(withFire[1][0])
withFireList.append(withFire[2][0])
withFireList.append(withFire[3][0])

plt.subplot(1, 2, 1)
plt.plot(range(6, 10), noFireList, label='No Fire', color='g')
plt.xticks(range(6, 10))
plt.legend(loc='lower center')
plt.xlabel('Months')
plt.ylabel('Average Temperature')
plt.title('Average Temperature Each Month no fire')

plt.subplot(1, 2, 2)
plt.plot(range(6, 10), withFireList, label='Fire')
plt.xticks(range(6, 10))
plt.legend(loc='lower center')

plt.xlabel('Months')
plt.ylabel('Average Temperature')
plt.title('Average Temperature Each Month fire')
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=1,
                    wspace=1.5)
plt.show()




# %%


# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    float64
#  13  Classes      122 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:129: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:129: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:129: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:129: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   noFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'not fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:130: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:130: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:130: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]
# /var/folders/hp/hfcws7b939v7w1hwtbvw4trr0000gn/T/ipykernel_47995/746273941.py:130: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   withFire = [df_b[['Temperature', 'month', 'Classes  ']][(df_b['month'] == month) & (df_b['Classes  '] == 'fire   ')].mean() for month in df_b['month'].unique()]
